# %% [markdown]
# # Retail Demand Forecasting – Data Analysis Notebook

# %%
import pandas as pd
print("✅ Kernel connected successfully!")

# %% [markdown]
# ## Step 1 – Load Dataset
# We start by loading the raw dataset from Kaggle to explore the structure and content.

# %%
import sys, pandas as pd
print("Python path:", sys.executable)
print("✅ Kernel connected and pandas working!")
# Out:
# Python path: /Users/elmifarah/Documents/retail-demand-forecasting/.venv/bin/python3
# ✅ Kernel connected and pandas working!
